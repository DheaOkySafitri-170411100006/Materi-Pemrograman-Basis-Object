# %% [markdown]
# # MATERI PBO (PYGAME)

# %% [markdown]
# 1. Pengertian Pygame
#
#     pygame yaitu modul cross-platform dari Python yang digunakan untuk membuat game. Modulnya dirancang untuk menjadi sederhana, mudah digunakan, dan tentunya juga menyenangkan. untuk dapat membuat game dengan menggunakan pygame, tentunya harus menginstall pygame terlebih dahulu

# %% [markdown]
# 2. Cara Instalasi Pygame
#
# a. Siapkan file pygame.whl
# Download library pygame di https://www.lfd.uci.edu/~gohlke/pythonlibs/ .Sesuaikan versi python yang terinstall dengan  versi library pygame yang akan di downlod.
#
# b. Mengubah file pygame.whl menjadi .zip
# kemudian mengubah extension file library pygame lalu extract isi library tersebut.
#
# c. Copy file pygame yang dibutuhkan
# pertama masuk ke dalam directory python (C:\Users\#username\AppData\Local\Programs\Python\Python35-32), kemudian masuk kedalam folder “include” dan buat folder baru bernama “pygame”. setelah itu, Di dalam folder hasil extract file library pygame yang sudah didownload, masuk ke “pygame-1.9.4.data\header”, copy semua file di dalam folder tersebut dan masukkan ke dalam folder: C:\Users\#username\AppData\Local\Programs\Python\Python35-32\include\pygame. Kemudian Di dalam folder hasil extract file library pygame yang sudah didownload, masuk ke “pygame-1.9.4.data\header”, copy semua file di dalam folder tersebut dan masukkan ke dalam folder: C:\Users\#username\AppData\Local\Programs\Python\Python35-32\include\pygame.
#
# d. Cek hasil installasi
# Buka IDLE Python kemudian lakukan perintah “import pygame”, jika tidak ada tulisan error maka pygame sudah berhasil terinstall.

# %% [markdown]
# 3. Instalasi SubClass
#
# Agar bisa menggunakan method-method ataupun event yang terdapat pada modul pygame, maka lakukanlah perintah import pygame, dengan cara mengetikkan "import pygame" di IDLE Python.

# %% [markdown]
# 4. Property Pygame
#
# a. Ada tiga warna dasar cahaya: merah, hijau dan biru.Merah, biru, dan kuning adalah warna utama untuk cat dan pigmen, Dengan menggabungkan jumlah yang berbeda dari ketiga warna ini Anda dapat membentuk warna lain. Dalam Pygame, warna dengan tuple dari tiga bilangan bulat. Nilai pertama dalam tupel adalah berapa merah dalam warna. Nilai integer 0 berarti tidak ada warna merah dalam warna ini, dan nilai 255 berarti ada jumlah maksimum warna merah. Nilai kedua untuk warna hijau dan nilai ketiga untuk warna biru. Ini tupel tiga bilangan bulat yang digunakan untuk mewakili warna sering disebut nilai-nilai RGB.
#
# b. Event
# event.type berfungsi sebagai kondisi, syntax-syntax dibawah event tersebut akan dieksekusi jika branchcondition pada event.type bernilai True.Jika Window Pygame di tutup (quit) maka akan menjalankan perintah untuk keluar, dan jika  (keydown) ditekan maka akan menjalankan perintah sesuai dengan perintah yang dimasukkan
#
# c. Object
# Pygame telah menyediakan beberapa objek yang dapat digunakan. Objek-objek yang dapat digunakan yaitu Rectangle, Circle, Polygon, Line, Ellipse.
#
# d. Menambahkan Gambar
# Untuk menambahkan gambar kedalam Pygame memerlukan 2 perintah dasar, yaitu menggunakan pygame.image.load() dan blit().
#
# e. FPS (Frame Per Second)
# Pemberian FPS dalam pygame bisa mengunakan time.clock() milik pygame. FPS diperlukan untuk memberikan efek animasi per detik, jika tidak memberikan efek FPS maka animasi akan berjalan langsung menuju animasi akhir.
#
# f. Pergerakan dibagi menjadi 2 jenis, pergerakan Statis dan Dinamis. Setiap pergerakan dalam Pygame harus berada dalam looping agar setiap pergerakan dapat dimuat ulang untuk ditampilkan. Pergerakkan Statis ini sangat tidak bergantung dengan inputan suatu event dan terus dieksekusi saat pertama kali dijalankan. Sedangkan pergerakan dinamis sangat bergantung dengan inputan suatu event terpenuhi.

# %% [markdown]
# 4. Contoh Pygame

# %%
#contoh game Shooter

import pygame
import random
 
# Define some colors
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
RED = (255, 0, 0)
BLUE = (0, 0, 255)
 
# --- Classes
 
 
class Block(pygame.sprite.Sprite):
    """ This class represents the block. """
    def __init__(self, color):
        # Call the parent class (Sprite) constructor
        super().__init__()
 
        #self.image = pygame.Surface([20, 15])
        #self.image.fill(color)
        self.image=pygame.image.load('meteor.png')
 
        self.rect = self.image.get_rect()
 
 
class Player(pygame.sprite.Sprite):
    """ This class represents the Player. """
 
    def __init__(self):
        """ Set up the player on creation. """
        # Call the parent class (Sprite) constructor
        super().__init__()
 
        #self.image = pygame.Surface([0, 50])
        #self.image.fill(RED)
        #self.image = pygame.Surface([width, height])
        self.image=pygame.image.load('shooter.png')
 
        self.rect = self.image.get_rect()
 
    def update(self):
        """ Update the player's position. """
        # Get the current mouse position. This returns the position
        # as a list of two numbers.
        
        pos = pygame.mouse.get_pos()
 
        # Set the player x position to the mouse x position
        self.rect.x = pos[0]
        
 
 
class Bullet(pygame.sprite.Sprite):
    """ This class represents the bullet . """
    def __init__(self):
        # Call the parent class (Sprite) constructor
        super().__init__()
 
        #self.image = pygame.Surface([4, 10])
        #self.image.fill(BLACK)
        self.image=pygame.image.load('missile.png')
 
        self.rect = self.image.get_rect()
 
    def update(self):
        """ Move the bullet. """
        self.rect.y -= 10 
 
 
# --- Create the window

# Initialize Pygame
pygame.init()
 
# Set the height and width of the screen
screen_width = 700
screen_height = 400
screen = pygame.display.set_mode([screen_width, screen_height])
backgroundg=pygame.image.load('main.png')

#screen = pygame.display.set_mode('main.png')

 
# --- Sprite lists
 
# This is a list of every sprite. All blocks and the player block as well.
all_sprites_list = pygame.sprite.Group()
 
# List of each block in the game
block_list = pygame.sprite.Group()
 
# List of each bullet
bullet_list = pygame.sprite.Group()
 
# --- Create the sprites
 
for i in range(50):
    # This represents a block
    block = Block(BLUE)
 
    # Set a random location for the block
    block.rect.x = random.randrange(screen_width)
    block.rect.y = random.randrange(300)
 
    # Add the block to the list of objects
    block_list.add(block)
    all_sprites_list.add(block)
 
# Create a red player block
player = Player()
all_sprites_list.add(player)
 
# Loop until the user clicks the close button.
done = False
 
# Used to manage how fast the screen updates
clock = pygame.time.Clock()
 
score = 0
player.rect.y = 370
 
# -------- Main Program Loop -----------
while not done:
    # --- Event Processing
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            done = True
 
        elif event.type == pygame.MOUSEBUTTONDOWN:
            # Fire a bullet if the user clicks the mouse button
            bullet = Bullet()
            # Set the bullet so it is where the player is
            bullet.rect.x = player.rect.x
            bullet.rect.y = player.rect.y
            # Add the bullet to the lists
            all_sprites_list.add(bullet)
            bullet_list.add(bullet)
 
    # --- Game logic
 
    # Call the update() method on all the sprites
    all_sprites_list.update()
 
    # Calculate mechanics for each bullet
    for bullet in bullet_list:
 
        # See if it hit a block
        block_hit_list = pygame.sprite.spritecollide(bullet, block_list, True)
 
        # For each block hit, remove the bullet and add to the score
        for block in block_hit_list:
            bullet_list.remove(bullet)
            all_sprites_list.remove(bullet)
            score += 5
            print(score)
 
        # Remove the bullet if it flies up off the screen
        if bullet.rect.y < -10:
            bullet_list.remove(bullet)
            all_sprites_list.remove(bullet)
 
    # --- Draw a frame
    
 
            
    # Clear the screen
    background_image = pygame.image.load("main.png").convert () 
    screen.fill(BLUE)

    #skor
    font = pygame.font.SysFont("serif",20)
    txt="Skor: {} ".format(score)
    text=font.render(txt,True,  RED)
    screen.blit(text,[15,10])
 
    # Draw all the spites
    all_sprites_list.draw(screen)
 
    # Go ahead and update the screen with what we've drawn.
    pygame.display.flip()

    
 
    # --- Limit to 20 frames per second
    clock.tick(60)
 
pygame.quit()
